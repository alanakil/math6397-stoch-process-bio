# %% [markdown]
# ## Computational Challenge 5
#
# Group \#4
#
# Students: Danial Asgari, Michael Batista, Youssaf Menacer, and Alan Akil
#
# Course: Math 6397 - Stochastic Processes in Biology
#
# Professors: Dr. Josić & Dr. Stewart
#
# $\textbf{Challenge:}$
#
#
# In this challenge two groups will report on the deterministic version of models of these circuits, while the other two will report on the stochastic versions. The last part of each question asks that you compare the results of the simulations. Therefore groups 1 and 2, and groups 3 and 4 will need to work together on each project.
#
# A feed-forward loop (FFL) is a 3-gene genetic circuit in which two “input” transcription factors (TFs), $X$ and $Y$, regulate a third “target” $Z$, with TF $X$ also regulating TF $Y$. Depending on the pattern of activation and repression among the three genes, an FFL can speed or slow the response time of $Z$ to a stimulus in the form of $X$ switching ON or OFF. Here we will explore the behavor of the so-called “incoherent” FFL.
# We will assume that X is either OFF or ON such that the concentration of the product of gene $X$ is $X_∗$ where $X_∗ =1$ when the geneis ON and $X∗ =0$when the gene is OFF. We will look at two specific cases of an incoherent FFL.
#
#
#
# Work with Group 3 to understand the behavior of the different circuits in response to changes in the input X.
#
# (a) Construct a Petri Net describing a stochastic version of the two FFLs. Assuming the ODEs describe concentrations, suggest reasonable values for reaction rates that will produce at most a few hundred molecules in the products of all three genes, while retaining the regulatory relationships of the deterministic system.
#
# (b) Implement a stochastic simulation corresponding to the two FFLs above using the Gillespie Algorithm.
#
# (c) Estimate the ON-to-OFF and OFF-to-ON response times with strong $Y−Z$ regulation for the two FFL cases.
#
# (d) Assuming $X$ is ON, plot the stationary distribution for the expression of $Z$ with strong $Y-Z$ regulation for the two FFL cases.

# %% [markdown]
# ## Petri Net of the system
# ![title](./Petri-comp-5.png)

# %%
# Import packages needed.
import numpy as np
import random
from scipy.special import gamma, factorial
import matplotlib.pyplot as plt
import seaborn as sns
import collections
import tqdm
from numba import jit
from numba import njit, prange
import time
from scipy.integrate import solve_ivp

# %% [markdown]
# ## Define the function for simulating Case 1 and 2

# %%
# @jit
def sim_case1(x,By,beta_y,alpha_y,Bz,beta_z,alpha_z,k_xy,k_xz,k_yz,T,time_on_init,time_on_end):
    # x=[Y,Z] is the molecule count of each species.
    t_x=[0] # reaction time of fully-observed trajectory
    i=0
    # Reaction matrix.
    v=np.array([[1,0],[-1,0],[0,1],[0,-1]])
    while t_x[i]<T:
        if time_on_init<t_x[i]<time_on_end:
            X=1
        else:
            X=0
        # Propensity functions
        a = np.array([By+beta_y * (((X/k_xy)**h)/(1+((X/k_xy)**h))), alpha_y * x[i,0],
                     Bz+beta_z * (((X/k_xz)**h)/(1+((X/k_xz)**h)))*(1/(1+((x[i,0]/k_yz)**h)))
                      ,alpha_z * x[i,1]])
        sum_a=np.sum(a)
        cumsum_a=np.cumsum(a,axis=0)
        # Draw 2 random numbers from U(0,1)
        epsilon=np.random.uniform(0,1,2)
        # Find the reaction that will take place next.
        j=np.min(np.where(epsilon[0]*sum_a<cumsum_a))
        # Compute the time until reaction j happens.
        tau=(np.log(1/epsilon[1]))/sum_a
        # Update molecule counts due to reaction j happening.
        x=np.append(x,[x[i,:]+v[j,:]],axis=0)
        # Update time of simulation.
        t_x=np.append(t_x,[t_x[i]+tau])
        i+=1
    return x,t_x

# @jit
def sim_case2(x,By,beta_y,alpha_y,Bz,beta_z,alpha_z,k_xy,k_xz,k_yz,T,time_on_init,time_on_end):
    # x=[Y,Z] is the molecule count of each species.
    t_x=[0] # reaction time of fully-observed trajectory
    i=0
    # Reaction matrix.
    v=np.array([[1,0],[-1,0],[0,1],[0,-1]])
    while t_x[i]<T:
        if time_on_init<t_x[i]<time_on_end:
            X=1
        else:
            X=0
        # Propensity functions
        a = np.array([By+beta_y * (1/(1+((X/k_xy)**h))), alpha_y * x[i,0],
                     Bz+beta_z * (1/(1+((X/k_xz)**h)))*(1/(1+((x[i,0]/k_yz)**h)))
                      ,alpha_z * x[i,1]])
        sum_a=np.sum(a)
        cumsum_a=np.cumsum(a,axis=0)
        # Draw 2 random numbers from U(0,1)
        epsilon=np.random.uniform(0,1,2)
        # Find the reaction that will take place next.
        j=np.min(np.where(epsilon[0]*sum_a<cumsum_a))
        # Compute the time until reaction j happens.
        tau=(np.log(1/epsilon[1]))/sum_a
        # Update molecule counts due to reaction j happening.
        x=np.append(x,[x[i,:]+v[j,:]],axis=0)
        # Update time of simulation.
        t_x=np.append(t_x,[t_x[i]+tau])
        i+=1
    return x,t_x

# %% [markdown]
# ## Sample simulation of case 1

# %%
# Case 1 - sample simulation
By = 1; beta_y = 3; alpha_y = 0.01;
Bz = 1; beta_z = 3; alpha_z = 0.01;
k_xy = 1; k_xz = 1; k_yz = 0.01 *10**0;
h = 0.1
y_0 = 10
z_0 = 10
x = np.array([y_0,z_0]).reshape(1,2)
T = 10000
time_on_init = T//3
time_on_end = 2*T//3

np.random.seed(2)

x,t_x = sim_case1(x,By,beta_y,alpha_y,Bz,beta_z,alpha_z,k_xy,k_xz,k_yz,T,time_on_init,time_on_end)


# Create figure and plot 
## Plot results
fig=plt.figure(figsize=(8,5))
ax = plt.subplot(111)

sns.set()
sns.set_style('whitegrid')
sns.set_style('white')
sns.set_style("ticks")
sns.set_context("talk", font_scale=1.4, rc={"lines.linewidth":2.3})

# Shade area where laser is ON.
ax.axvspan(time_on_init, time_on_end, alpha=0.2, color='black')

plt.plot(t_x,x[:,0],label='Y')
plt.plot(t_x,x[:,1],label='Z')

plt.xlabel('Time')
plt.ylabel('Concentration')

plt.legend()
sns.despine()

plt.title(r'Sample sim - case I')

plt.show()

print('Shaded area indicates that X was ON.')
# Out:
# Shaded area indicates that X was ON

# %% [markdown]
# ## Sample simulation of case 2

# %%
# Case 2 - sample simulation
By = 1; beta_y = 3; alpha_y = 0.01;
Bz = 1; beta_z = 3; alpha_z = 0.01;
k_xy = 1; k_xz = 1; k_yz = 0.01 *10**0;
h = 0.1
y_0 = 10
z_0 = 10
x = np.array([y_0,z_0]).reshape(1,2)
T = 10000
time_on_init = T//3
time_on_end = 2*T//3

np.random.seed(2)

x,t_x = sim_case2(x,By,beta_y,alpha_y,Bz,beta_z,alpha_z,k_xy,k_xz,k_yz,T,time_on_init,time_on_end)


# Create figure and plot 
## Plot results
fig=plt.figure(figsize=(8,5))
ax = plt.subplot(111)

sns.set()
sns.set_style('whitegrid')
sns.set_style('white')
sns.set_style("ticks")
sns.set_context("talk", font_scale=1.4, rc={"lines.linewidth":2.3})

# Shade area where laser is ON.
ax.axvspan(time_on_init, time_on_end, alpha=0.2, color='black')

plt.plot(t_x,x[:,0],label='Y')
plt.plot(t_x,x[:,1],label='Z')

plt.xlabel('Time')
plt.ylabel('Concentration')

plt.legend()
sns.despine()

plt.title(r'Sample sim - case II')

plt.show()

print('Shaded area indicates that X was ON.')
# Out:
# /opt/anaconda3/envs/bmnn/lib/python3.7/site-packages/IPython/core/pylabtools.py:132: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)
# Shaded area indicates that X was ON.

# %% [markdown]
# ## How does varying $Y-Z$ regulation affect Y and Z?

# %%
# Case 1 - varying Y - Z regulation
By = 1; beta_y = 3; alpha_y = 0.01;
Bz = 1; beta_z = 3; alpha_z = 0.01;
k_xy = 1; k_xz = 1; k_yz = 0.001 *10**0;
h = 0.1
y_0 = 10
z_0 = 10
x = np.array([y_0,z_0]).reshape(1,2)
T = 10000
time_on_init = T//3
time_on_end = 2*T//3

np.random.seed(2)

print('Case 1')

x,t_x = sim_case1(x,By,beta_y,alpha_y,Bz,beta_z,alpha_z,k_xy,k_xz,k_yz,T,time_on_init,time_on_end)

fig, axs = plt.subplots(2, 2, figsize=(16,10))
axs[0, 0].plot(t_x, x[:,0],label='Y')
axs[0, 0].plot(t_x, x[:,1],label='Z')
axs[0, 0].set_title('k_yz=0.001')
axs[0, 0].legend()
axs[0, 0].axvspan(time_on_init, time_on_end, alpha=0.2, color='black')

x = np.array([y_0,z_0]).reshape(1,2)
k_yz = 0.1
x,t_x = sim_case1(x,By,beta_y,alpha_y,Bz,beta_z,alpha_z,k_xy,k_xz,k_yz,T,time_on_init,time_on_end)
axs[0, 1].plot(t_x, x[:,0])
axs[0, 1].plot(t_x, x[:,1])
axs[0, 1].set_title('k_yz=0.1')
axs[0, 1].axvspan(time_on_init, time_on_end, alpha=0.2, color='black')

x = np.array([y_0,z_0]).reshape(1,2)
k_yz = 1
x,t_x = sim_case1(x,By,beta_y,alpha_y,Bz,beta_z,alpha_z,k_xy,k_xz,k_yz,T,time_on_init,time_on_end)
axs[1, 0].plot(t_x, x[:,0])
axs[1, 0].plot(t_x, x[:,1])
axs[1, 0].set_title('k_yz=1')
axs[1, 0].axvspan(time_on_init, time_on_end, alpha=0.2, color='black')

x = np.array([y_0,z_0]).reshape(1,2)
k_yz = 10**3
x,t_x = sim_case1(x,By,beta_y,alpha_y,Bz,beta_z,alpha_z,k_xy,k_xz,k_yz,T,time_on_init,time_on_end)
axs[1, 1].plot(t_x, x[:,0])
axs[1, 1].plot(t_x, x[:,1])
axs[1, 1].set_title('k_yz=1000')
axs[1, 1].axvspan(time_on_init, time_on_end, alpha=0.2, color='black')


for ax in axs.flat:
    ax.set(xlabel='Time', ylabel='Concentration')

# Hide x labels and tick labels for top plots and y ticks for right plots.
for ax in axs.flat:
    ax.label_outer()
# Out:
# Case 1

# %%
# Case 2 - varying Y - Z regulation
By = 1; beta_y = 3; alpha_y = 0.01;
Bz = 1; beta_z = 3; alpha_z = 0.01;
k_xy = 1; k_xz = 1; k_yz = 0.001 *10**0;
h = 0.1
y_0 = 10
z_0 = 10
x = np.array([y_0,z_0]).reshape(1,2)
T = 10000
time_on_init = T//3
time_on_end = 2*T//3

np.random.seed(2)

print('Case 2')

x,t_x = sim_case2(x,By,beta_y,alpha_y,Bz,beta_z,alpha_z,k_xy,k_xz,k_yz,T,time_on_init,time_on_end)

fig, axs = plt.subplots(2, 2, figsize=(16,10))
axs[0, 0].plot(t_x, x[:,0],label='Y')
axs[0, 0].plot(t_x, x[:,1],label='Z')
axs[0, 0].set_title('k_yz=0.001')
axs[0, 0].legend()
axs[0, 0].axvspan(time_on_init, time_on_end, alpha=0.2, color='black')

x = np.array([y_0,z_0]).reshape(1,2)
k_yz = 0.1
x,t_x = sim_case2(x,By,beta_y,alpha_y,Bz,beta_z,alpha_z,k_xy,k_xz,k_yz,T,time_on_init,time_on_end)
axs[0, 1].plot(t_x, x[:,0])
axs[0, 1].plot(t_x, x[:,1])
axs[0, 1].set_title('k_yz=0.1')
axs[0, 1].axvspan(time_on_init, time_on_end, alpha=0.2, color='black')

x = np.array([y_0,z_0]).reshape(1,2)
k_yz = 1
x,t_x = sim_case2(x,By,beta_y,alpha_y,Bz,beta_z,alpha_z,k_xy,k_xz,k_yz,T,time_on_init,time_on_end)
axs[1, 0].plot(t_x, x[:,0])
axs[1, 0].plot(t_x, x[:,1])
axs[1, 0].set_title('k_yz=1')
axs[1, 0].axvspan(time_on_init, time_on_end, alpha=0.2, color='black')

x = np.array([y_0,z_0]).reshape(1,2)
k_yz = 10**3
x,t_x = sim_case2(x,By,beta_y,alpha_y,Bz,beta_z,alpha_z,k_xy,k_xz,k_yz,T,time_on_init,time_on_end)
axs[1, 1].plot(t_x, x[:,0])
axs[1, 1].plot(t_x, x[:,1])
axs[1, 1].set_title('k_yz=1000')
axs[1, 1].axvspan(time_on_init, time_on_end, alpha=0.2, color='black')


for ax in axs.flat:
    ax.set(xlabel='Time', ylabel='Concentration')

# Hide x labels and tick labels for top plots and y ticks for right plots.
for ax in axs.flat:
    ax.label_outer()
# Out:
# Case 2
# /opt/anaconda3/envs/bmnn/lib/python3.7/site-packages/IPython/core/pylabtools.py:132: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# ## Estimate the ON-to-OFF and OFF-to-ON response times with strong $Y-Z$ regulation

# %%
# Case 1 - Response time calculation - high k_yz
By = 1; beta_y = 3; alpha_y = 0.01;
Bz = 1; beta_z = 3; alpha_z = 0.01;
k_xy = 1; k_xz = 1; k_yz = 0.01 *10**5;
h = 0.1
y_0 = 10
z_0 = 10
x = np.array([y_0,z_0]).reshape(1,2)
T = 10000
time_on_init = T//3
time_on_end = 2*T//3

Num_realizations = 200
response_time_off_to_on = np.zeros(Num_realizations)
response_time_on_to_off = np.zeros(Num_realizations)
threshold = 5

for i in range(Num_realizations):
    start_time = time.time() # start timing
    np.random.seed(i)
    x = np.array([y_0,z_0]).reshape(1,2)
    x,t_x = sim_case1(x,By,beta_y,alpha_y,Bz,beta_z,alpha_z,
                      k_xy,k_xz,k_yz,T,time_on_init,time_on_end)
    # Compute OFF to ON response time
    indx_start_X_on = np.argmin(np.abs(t_x-T//3))
    indx_end_X_on = np.argmin(np.abs(t_x-2*T//3))
    x_mean_X_on = np.mean(x[indx_start_X_on:indx_end_X_on,1])
    response_time_off_to_on[i] = t_x[(np.abs(x[:,1]-x_mean_X_on)<threshold)][0]- time_on_init
    # Compute ON to OFF response time
    x_mean_X_off = np.mean(x[indx_end_X_on:-1,1])
    response_time_on_to_off[i] = t_x[(np.abs(x[:,1]-x_mean_X_off)<threshold) 
                                     & (t_x>2*T//3)][0] - time_on_end
    stop_time = time.time() # stop timing
    print('Simulation time:',stop_time-start_time,'sec')
# Out:
# Simulation time: 4.186168193817139 sec
# Simulation time: 4.3191139698028564 sec
# Simulation time: 4.7519307136535645 sec
# Simulation time: 4.074310302734375 sec
# Simulation time: 4.528484106063843 sec
# Simulation time: 4.131413221359253 sec
# Simulation time: 4.4819111824035645 sec
# Simulation time: 4.396237134933472 sec
# Simulation time: 4.273483991622925 sec
# Simulation time: 4.153943777084351 sec
# Simulation time: 4.1761085987091064 sec
# Simulation time: 4.096384763717651 sec
# Simulation time: 4.130431890487671 sec
# Simulation time: 4.149372339248657 sec
# Simulation time: 4.137410879135132 sec
# Simulation time: 4.089859247207642 sec
# Simulation time: 3.9595320224761963 sec
# Simulation time: 3.9804399013519287 sec
# Simulation time: 4.06545090675354 sec
# Simulation time: 4.012998819351196 sec
# Simulation time: 3.8917598724365234 sec
# Simulation time: 4.12038516998291 sec
# Simulation time: 4.1528449058532715 sec
# Simulation time: 4.000303268432617 sec
# Simulation time: 4.371323108673096 sec
# Simulation time: 5.089428901672363 sec
# Simulation time: 5.089854001998901 sec
# Simulation time: 4.190253019332886 sec
# Simulation time: 4.212316036224365 sec
# Simulation time: 4.175537824630737 sec
# Simulation time: 3.927640914916992 sec
# Simulation time: 3.8892297744750977 sec
# Simulation time: 3.9761860370635986 sec
# Simulation time: 3.9255340099334717 sec
# Simulation time: 3.995213031768799 sec
# Simulation time: 3.9394690990448 sec
# Simulation time: 3.985614061355591 sec
# Simulation time: 3.9340920448303223 sec
# Simulation time: 4.019489765167236 sec
# Simulation time: 3.951495885848999 sec
# Simulation time: 3.883157968521118 sec
# Simulation time: 4.118659257888794 sec
# Simulation time: 4.0666399002075195 sec
# Simulation time: 4.059117078781128 sec
# Simulation time: 4.147247791290283 sec
# Simulation time: 4.015804052352905 sec
# Simulation time: 4.010035991668701 sec
# Simulation time: 4.046244859695435 sec
# Simulation time: 4.0642571449279785 sec
# Simulation time: 3.9458167552948 sec
# Simulation time: 4.065400838851929 sec
# Simulation time: 3.992526054382324 sec
# Simulation time: 3.9036359786987305 sec
# Simulation time: 3.9798460006713867 sec
# Simulation time: 3.8579320907592773 sec
# Simulation time: 3.8837499618530273 sec
# Simulation time: 3.9802441596984863 sec
# Simulation time: 3.8597092628479004 sec
# Simulation time: 4.003242015838623 sec
# Simulation time: 4.017433166503906 sec
# Simulation time: 3.9794511795043945 sec
# Simulation time: 4.086045026779175 sec
# Simulation time: 3.891314744949341 sec
# Simulation time: 3.936412811279297 sec
# Simulation time: 3.9301598072052 sec
# Simulation time: 4.0120530128479 sec
# Simulation time: 3.9750750064849854 sec
# Simulation time: 4.019958019256592 sec
# Simulation time: 3.8887438774108887 sec
# Simulation time: 3.9670660495758057 sec
# Simulation time: 3.971101999282837 sec
# Simulation time: 3.923286199569702 sec
# Simulation time: 4.0512778759002686 sec
# Simulation time: 4.030876874923706 sec
# Simulation time: 4.018965005874634 sec
# Simulation time: 3.9911868572235107 sec
# Simulation time: 3.9767098426818848 sec
# Simulation time: 3.937873125076294 sec
# Simulation time: 4.0627121925354 sec
# Simulation time: 4.025689125061035 sec
# Simulation time: 3.9690189361572266 sec
# Simulation time: 4.018535852432251 sec
# Simulation time: 3.9829068183898926 sec
# Simulation time: 3.950611114501953 sec
# Simulation time: 3.979509115219116 sec
# Simulation time: 3.9475600719451904 sec
# Simulation time: 3.956087112426758 sec
# Simulation time: 3.9319891929626465 sec
# Simulation time: 3.8590519428253174 sec
# Simulation time: 3.824207305908203 sec
# Simulation time: 3.941030979156494 sec
# Simulation time: 3.8593788146972656 sec
# Simulation time: 3.8802921772003174 sec
# Simulation time: 3.9337329864501953 sec
# Simulation time: 3.9832661151885986 sec
# Simulation time: 3.8859519958496094 sec
# Simulation time: 3.988940954208374 sec
# Simulation time: 4.025359869003296 sec
# Simulation time: 3.9599668979644775 sec
# Simulation time: 4.034553050994873 sec
# Simulation time: 3.9836087226867676 sec
# Simulation time: 3.8913562297821045 sec
# Simulation time: 3.909799337387085 sec
# Simulation time: 3.9302561283111572 sec
# Simulation time: 3.963167905807495 sec
# Simulation time: 4.0344250202178955 sec
# Simulation time: 4.373545169830322 sec
# Simulation time: 4.026396751403809 sec
# Simulation time: 4.389700174331665 sec
# Simulation time: 4.143754005432129 sec
# Simulation time: 4.100963115692139 sec
# Simulation time: 4.482056140899658 sec
# Simulation time: 4.1430840492248535 sec
# Simulation time: 4.595199108123779 sec
# Simulation time: 4.516841888427734 sec
# Simulation time: 4.446243762969971 sec
# Simulation time: 3.9162769317626953 sec
# Simulation time: 4.097001791000366 sec
# Simulation time: 4.084423065185547 sec
# Simulation time: 4.194847345352173 sec
# Simulation time: 4.395944118499756 sec
# Simulation time: 4.6615941524505615 sec
# Simulation time: 4.419489145278931 sec
# Simulation time: 4.120297908782959 sec
# Simulation time: 4.428854942321777 sec
# Simulation time: 4.469714879989624 sec
# Simulation time: 4.604419946670532 sec
# Simulation time: 4.240687847137451 sec
# Simulation time: 4.016824960708618 sec
# Simulation time: 4.3041980266571045 sec
# Simulation time: 4.6260762214660645 sec
# Simulation time: 4.734438180923462 sec
# Simulation time: 4.65919303894043 sec
# Simulation time: 4.266043186187744 sec
# Simulation time: 4.303213119506836 sec
# Simulation time: 4.136204242706299 sec
# Simulation time: 4.12295126914978 sec
# Simulation time: 4.274703025817871 sec
# Simulation time: 4.170696973800659 sec
# Simulation time: 4.410405158996582 sec
# Simulation time: 4.282680034637451 sec
# Simulation time: 4.31953501701355 sec
# Simulation time: 3.923569917678833 sec
# Simulation time: 4.256986856460571 sec
# Simulation time: 4.011328935623169 sec
# Simulation time: 4.189570903778076 sec
# Simulation time: 4.385639905929565 sec
# Simulation time: 4.398350715637207 sec
# Simulation time: 4.416400909423828 sec
# Simulation time: 4.318218946456909 sec
# Simulation time: 4.31847620010376 sec
# Simulation time: 4.440119981765747 sec
# Simulation time: 4.713602781295776 sec
# Simulation time: 4.620358943939209 sec
# Simulation time: 4.602248907089233 sec
# Simulation time: 4.703784227371216 sec
# Simulation time: 4.038921117782593 sec
# Simulation time: 3.9601237773895264 sec
# Simulation time: 3.9639809131622314 sec
# Simulation time: 4.030327081680298 sec
# Simulation time: 3.9851107597351074 sec
# Simulation time: 3.9673290252685547 sec
# Simulation time: 3.91206693649292 sec
# Simulation time: 3.947840929031372 sec
# Simulation time: 3.9503390789031982 sec
# Simulation time: 3.9026241302490234 sec
# Simulation time: 3.967510938644409 sec
# Simulation time: 4.081301927566528 sec
# Simulation time: 4.0183868408203125 sec
# Simulation time: 4.144243955612183 sec
# Simulation time: 4.021553039550781 sec
# Simulation time: 4.023778915405273 sec
# Simulation time: 4.051506042480469 sec
# Simulation time: 4.1582090854644775 sec
# Simulation time: 4.006361722946167 sec
# Simulation time: 4.063982963562012 sec
# Simulation time: 3.9612538814544678 sec
# Simulation time: 3.898592948913574 sec
# Simulation time: 3.8936121463775635 sec
# Simulation time: 3.946031093597412 sec
# Simulation time: 4.030476093292236 sec
# Simulation time: 4.024825096130371 sec
# Simulation time: 4.0749430656433105 sec
# Simulation time: 4.006799221038818 sec
# Simulation time: 3.935960054397583 sec
# Simulation time: 3.937206745147705 sec
# Simulation time: 3.9607460498809814 sec
# Simulation time: 4.023109197616577 sec
# Simulation time: 4.034592151641846 sec
# Simulation time: 3.8793628215789795 sec
# Simulation time: 4.001828193664551 sec
# Simulation time: 4.007622957229614 sec
# Simulation time: 3.9965171813964844 sec
# Simulation time: 3.9657270908355713 sec
# Simulation time: 3.9849941730499268 sec
# Simulation time: 4.041388988494873 sec
# Simulation time: 3.9654898643493652 sec
# Simulation time: 4.107566833496094 sec
# Simulation time: 3.90541410446167 sec
# Simulation time: 3.8769919872283936 sec

# %%
print('Case 1, High k_yz')
# Create figure and plot 
fig, axs = plt.subplots(1, 2, figsize=(16,5))
axs[0].hist(response_time_off_to_on,bins=50,color='blue')
axs[0].set_title('OFF to ON')
axs[0].axvline(x=np.mean(response_time_off_to_on),color='green',
              linewidth=5)

axs[1].hist(response_time_on_to_off,bins=50,color='red')
axs[1].set_title('ON to OFF')
axs[1].axvline(x=np.mean(response_time_on_to_off),color='darkmagenta',
              linewidth=5)

for ax in axs.flat:
    ax.set(xlabel='Response time', ylabel='Count',
          xlim=(0,700))
    
# Hide x labels and tick labels for top plots and y ticks for right plots.
for ax in axs.flat:
    ax.label_outer()

sns.despine()
    
plt.show()
# Out:
# Case 1, High k_yz

# %%
# Case 1 - Response time calculation - low k_yz
By = 1; beta_y = 3; alpha_y = 0.01;
Bz = 1; beta_z = 3; alpha_z = 0.01;
k_xy = 1; k_xz = 1; k_yz = 0.01 *10**0;
h = 0.1
y_0 = 10
z_0 = 10
x = np.array([y_0,z_0]).reshape(1,2)
T = 10000
time_on_init = T//3
time_on_end = 2*T//3

Num_realizations = 200
response_time_off_to_on = np.zeros(Num_realizations)
response_time_on_to_off = np.zeros(Num_realizations)
threshold = 5

# @jit()
for i in range(Num_realizations):
    start_time = time.time() # start timing
    np.random.seed(i)
    x = np.array([y_0,z_0]).reshape(1,2)
    x,t_x = sim_case1(x,By,beta_y,alpha_y,Bz,beta_z,alpha_z,
                      k_xy,k_xz,k_yz,T,time_on_init,time_on_end)
    # Compute OFF to ON response time
    indx_start_X_on = np.argmin(np.abs(t_x-T//3))
    indx_end_X_on = np.argmin(np.abs(t_x-2*T//3))
    x_mean_X_on = np.mean(x[indx_start_X_on:indx_end_X_on,1])
    response_time_off_to_on[i] = t_x[(np.abs(x[:,1]-x_mean_X_on)<threshold)][0]- time_on_init
    # Compute ON to OFF response time
    x_mean_X_off = np.mean(x[indx_end_X_on:-1,1])
    response_time_on_to_off[i] = t_x[(np.abs(x[:,1]-x_mean_X_off)<threshold) 
                                     & (t_x>2*T//3)][0] - time_on_end
    stop_time = time.time() # stop timing
    print('Simulation time:',stop_time-start_time,'sec')
# Out:
# Simulation time: 4.391679048538208 sec
# Simulation time: 4.094732046127319 sec
# Simulation time: 3.9784460067749023 sec
# Simulation time: 3.695939064025879 sec
# Simulation time: 3.6792750358581543 sec
# Simulation time: 3.765768051147461 sec
# Simulation time: 3.7323548793792725 sec
# Simulation time: 3.6957998275756836 sec
# Simulation time: 3.8142621517181396 sec
# Simulation time: 3.713336944580078 sec
# Simulation time: 3.603564739227295 sec
# Simulation time: 3.7681572437286377 sec
# Simulation time: 3.6775031089782715 sec
# Simulation time: 3.7410550117492676 sec
# Simulation time: 3.75396990776062 sec
# Simulation time: 3.6500911712646484 sec
# Simulation time: 3.691757917404175 sec
# Simulation time: 3.7588400840759277 sec
# Simulation time: 3.6848199367523193 sec
# Simulation time: 3.8260209560394287 sec
# Simulation time: 3.876422882080078 sec
# Simulation time: 3.8203577995300293 sec
# Simulation time: 3.87626314163208 sec
# Simulation time: 3.772697925567627 sec
# Simulation time: 3.8253839015960693 sec
# Simulation time: 3.848783254623413 sec
# Simulation time: 3.915755033493042 sec
# Simulation time: 4.048842906951904 sec
# Simulation time: 3.872954845428467 sec
# Simulation time: 3.825836181640625 sec
# Simulation time: 3.839743137359619 sec
# Simulation time: 3.7237141132354736 sec
# Simulation time: 3.905496835708618 sec
# Simulation time: 4.078603029251099 sec
# Simulation time: 4.7360968589782715 sec
# Simulation time: 4.724798917770386 sec
# Simulation time: 4.745836019515991 sec
# Simulation time: 4.719974994659424 sec
# Simulation time: 5.0599658489227295 sec
# Simulation time: 4.877431631088257 sec
# Simulation time: 4.7079057693481445 sec
# Simulation time: 4.0684850215911865 sec
# Simulation time: 4.629946947097778 sec
# Simulation time: 4.540334224700928 sec
# Simulation time: 4.593842029571533 sec
# Simulation time: 4.210431098937988 sec
# Simulation time: 4.117873907089233 sec
# Simulation time: 4.220706939697266 sec
# Simulation time: 4.35932183265686 sec
# Simulation time: 4.126163005828857 sec
# Simulation time: 4.101661205291748 sec
# Simulation time: 4.061585187911987 sec
# Simulation time: 3.951517343521118 sec
# Simulation time: 4.086704969406128 sec
# Simulation time: 4.047829866409302 sec
# Simulation time: 3.8826630115509033 sec
# Simulation time: 3.8704819679260254 sec
# Simulation time: 4.176122188568115 sec
# Simulation time: 4.472074747085571 sec
# Simulation time: 4.122089385986328 sec
# Simulation time: 4.176167011260986 sec
# Simulation time: 4.218349933624268 sec
# Simulation time: 4.123584985733032 sec
# Simulation time: 4.318994760513306 sec
# Simulation time: 3.98786997795105 sec
# Simulation time: 3.9180221557617188 sec
# Simulation time: 4.06306004524231 sec
# Simulation time: 4.085610866546631 sec
# Simulation time: 3.896428108215332 sec
# Simulation time: 3.9731149673461914 sec
# Simulation time: 3.9802732467651367 sec
# Simulation time: 3.948538064956665 sec
# Simulation time: 3.996184825897217 sec
# Simulation time: 3.7998788356781006 sec
# Simulation time: 3.826915740966797 sec
# Simulation time: 3.8380379676818848 sec
# Simulation time: 3.7914249897003174 sec
# Simulation time: 3.87943172454834 sec
# Simulation time: 3.749330997467041 sec
# Simulation time: 3.938817024230957 sec
# Simulation time: 4.167428016662598 sec
# Simulation time: 3.9967591762542725 sec
# Simulation time: 4.190693140029907 sec
# Simulation time: 4.201237916946411 sec
# Simulation time: 4.061238050460815 sec
# Simulation time: 4.006235837936401 sec
# Simulation time: 4.02021598815918 sec
# Simulation time: 3.9556329250335693 sec
# Simulation time: 3.972219705581665 sec
# Simulation time: 3.952840805053711 sec
# Simulation time: 4.027217149734497 sec
# Simulation time: 4.146492004394531 sec
# Simulation time: 4.160248756408691 sec
# Simulation time: 4.144004821777344 sec
# Simulation time: 3.969210147857666 sec
# Simulation time: 3.8495242595672607 sec
# Simulation time: 3.8065102100372314 sec
# Simulation time: 3.7138702869415283 sec
# Simulation time: 3.742738962173462 sec
# Simulation time: 3.718743085861206 sec
# Simulation time: 3.8367927074432373 sec
# Simulation time: 3.867440938949585 sec
# Simulation time: 3.76802134513855 sec
# Simulation time: 3.8112781047821045 sec
# Simulation time: 3.690052032470703 sec
# Simulation time: 3.6922857761383057 sec
# Simulation time: 3.956278085708618 sec
# Simulation time: 3.7993593215942383 sec
# Simulation time: 3.9956741333007812 sec
# Simulation time: 4.04543399810791 sec
# Simulation time: 4.1277711391448975 sec
# Simulation time: 4.1722047328948975 sec
# Simulation time: 4.035508871078491 sec
# Simulation time: 3.9128129482269287 sec
# Simulation time: 3.9006829261779785 sec
# Simulation time: 4.129487752914429 sec
# Simulation time: 4.1356401443481445 sec
# Simulation time: 4.08329701423645 sec
# Simulation time: 4.026141166687012 sec
# Simulation time: 4.124307870864868 sec
# Simulation time: 4.095327854156494 sec
# Simulation time: 3.943552017211914 sec
# Simulation time: 3.9442999362945557 sec
# Simulation time: 4.093979835510254 sec
# Simulation time: 4.031597852706909 sec
# Simulation time: 3.846895217895508 sec
# Simulation time: 3.9060728549957275 sec
# Simulation time: 3.737323045730591 sec
# Simulation time: 3.847775936126709 sec
# Simulation time: 3.9818038940429688 sec
# Simulation time: 4.046774864196777 sec
# Simulation time: 3.847815990447998 sec
# Simulation time: 3.9740309715270996 sec
# Simulation time: 3.9947619438171387 sec
# Simulation time: 3.980120897293091 sec
# Simulation time: 4.035568952560425 sec
# Simulation time: 3.9509310722351074 sec
# Simulation time: 3.998486042022705 sec
# Simulation time: 3.8268251419067383 sec
# Simulation time: 4.5517168045043945 sec
# Simulation time: 4.607148885726929 sec
# Simulation time: 4.020539999008179 sec
# Simulation time: 4.3018388748168945 sec
# Simulation time: 4.309347629547119 sec
# Simulation time: 3.8949880599975586 sec
# Simulation time: 4.160183906555176 sec
# Simulation time: 4.249711990356445 sec
# Simulation time: 4.038777828216553 sec
# Simulation time: 4.1249167919158936 sec
# Simulation time: 4.089917182922363 sec
# Simulation time: 4.386337995529175 sec
# Simulation time: 4.399930238723755 sec
# Simulation time: 4.149521350860596 sec
# Simulation time: 3.912881851196289 sec
# Simulation time: 3.8524529933929443 sec
# Simulation time: 3.91094708442688 sec
# Simulation time: 3.9727160930633545 sec
# Simulation time: 4.018477201461792 sec
# Simulation time: 3.848972797393799 sec
# Simulation time: 3.9384679794311523 sec
# Simulation time: 4.140472173690796 sec
# Simulation time: 3.79343581199646 sec
# Simulation time: 3.964226007461548 sec
# Simulation time: 4.00101900100708 sec
# Simulation time: 3.947624921798706 sec
# Simulation time: 3.890687942504883 sec
# Simulation time: 3.8103160858154297 sec
# Simulation time: 3.7770071029663086 sec
# Simulation time: 4.078134059906006 sec
# Simulation time: 3.8905138969421387 sec
# Simulation time: 3.863862991333008 sec
# Simulation time: 3.773087978363037 sec
# Simulation time: 4.020794868469238 sec
# Simulation time: 4.054868936538696 sec
# Simulation time: 4.05876612663269 sec
# Simulation time: 3.8895440101623535 sec
# Simulation time: 3.9767067432403564 sec
# Simulation time: 3.8579702377319336 sec
# Simulation time: 4.036067962646484 sec
# Simulation time: 4.079385995864868 sec
# Simulation time: 3.845637798309326 sec
# Simulation time: 3.8608779907226562 sec
# Simulation time: 3.8455469608306885 sec
# Simulation time: 3.966524124145508 sec
# Simulation time: 3.9366772174835205 sec
# Simulation time: 4.1397788524627686 sec
# Simulation time: 4.035175800323486 sec
# Simulation time: 3.9634411334991455 sec
# Simulation time: 3.9781079292297363 sec
# Simulation time: 4.0163819789886475 sec
# Simulation time: 3.947071075439453 sec
# Simulation time: 4.074552059173584 sec
# Simulation time: 4.047453165054321 sec
# Simulation time: 4.074624061584473 sec
# Simulation time: 4.000331163406372 sec
# Simulation time: 4.154564142227173 sec
# Simulation time: 4.085923194885254 sec
# Simulation time: 4.084513902664185 sec
# Simulation time: 4.048027276992798 sec
# Simulation time: 4.005336046218872 sec

# %%
print('Case 1, Low k_yz')
# Create figure and plot 
fig, axs = plt.subplots(1, 2, figsize=(16,5))
axs[0].hist(response_time_off_to_on,bins=50,color='blue')
axs[0].set_title('OFF to ON')
axs[0].axvline(x=np.mean(response_time_off_to_on),color='green',
              linewidth=5)

axs[1].hist(response_time_on_to_off,bins=50,color='red')
axs[1].set_title('ON to OFF')
axs[1].axvline(x=np.mean(response_time_on_to_off),color='darkmagenta',
              linewidth=5)

# for ax in axs.flat:
#     ax.set(xlabel='Response time', ylabel='Count',
#           xlim=(0,700))
    
# Hide x labels and tick labels for top plots and y ticks for right plots.
for ax in axs.flat:
    ax.label_outer()

sns.despine()
    
plt.show()
# Out:
# Case 1, Low k_yz

# %%
# Case 2 - Response time calculation - high k_yz
By = 1; beta_y = 3; alpha_y = 0.01;
Bz = 1; beta_z = 3; alpha_z = 0.01;
k_xy = 1; k_xz = 1; k_yz = 0.01 *10**5;
h = 0.1
y_0 = 10
z_0 = 10
x = np.array([y_0,z_0]).reshape(1,2)
T = 10000
time_on_init = T//3
time_on_end = 2*T//3

Num_realizations = 200
response_time_off_to_on = np.zeros(Num_realizations)
response_time_on_to_off = np.zeros(Num_realizations)
threshold = 5

for i in range(Num_realizations):
    start_time = time.time() # start timing
    np.random.seed(i)
    x = np.array([y_0,z_0]).reshape(1,2)
    x,t_x = sim_case2(x,By,beta_y,alpha_y,Bz,beta_z,alpha_z,
                      k_xy,k_xz,k_yz,T,time_on_init,time_on_end)
    # Compute OFF to ON response time
    indx_start_X_on = np.argmin(np.abs(t_x-T//3))
    indx_end_X_on = np.argmin(np.abs(t_x-2*T//3))
    x_mean_X_on = np.mean(x[indx_start_X_on:indx_end_X_on,1])
    response_time_off_to_on[i] = t_x[(np.abs(x[:,1]-x_mean_X_on)<threshold) 
                                     & (t_x>time_on_init)][0] - time_on_init
    # Compute ON to OFF response time
    x_mean_X_off = np.mean(x[indx_end_X_on:-1,1])
    response_time_on_to_off[i] = t_x[(np.abs(x[:,1]-x_mean_X_off)<threshold) 
                                     & (t_x>time_on_end)][0] - time_on_end
    stop_time = time.time() # stop timing
    print('Simulation time:',stop_time-start_time,'sec')
# Out:
# Simulation time: 11.51199722290039 sec
# Simulation time: 11.875361919403076 sec
# Simulation time: 11.689822912216187 sec
# Simulation time: 11.719320058822632 sec
# Simulation time: 11.639132261276245 sec
# Simulation time: 11.72652006149292 sec
# Simulation time: 11.847568035125732 sec
# Simulation time: 11.84050464630127 sec
# Simulation time: 11.530910968780518 sec
# Simulation time: 11.723587036132812 sec
# Simulation time: 11.906147241592407 sec
# Simulation time: 11.700560092926025 sec
# Simulation time: 11.645179033279419 sec
# Simulation time: 11.63148307800293 sec
# Simulation time: 11.765355110168457 sec
# Simulation time: 11.5031418800354 sec
# Simulation time: 11.683726072311401 sec
# Simulation time: 12.028486728668213 sec
# Simulation time: 11.858422040939331 sec
# Simulation time: 11.788347959518433 sec
# Simulation time: 11.875186920166016 sec
# Simulation time: 11.695908069610596 sec
# Simulation time: 11.59086799621582 sec
# Simulation time: 11.695401191711426 sec
# Simulation time: 11.906990766525269 sec
# Simulation time: 11.669500827789307 sec
# Simulation time: 11.613691806793213 sec
# Simulation time: 11.832902908325195 sec
# Simulation time: 11.579137086868286 sec
# Simulation time: 11.623520135879517 sec
# Simulation time: 11.584446907043457 sec
# Simulation time: 11.586731910705566 sec
# Simulation time: 11.638605117797852 sec
# Simulation time: 11.7634859085083 sec
# Simulation time: 11.595416784286499 sec
# Simulation time: 11.932073831558228 sec
# Simulation time: 11.725557088851929 sec
# Simulation time: 11.858506917953491 sec
# Simulation time: 11.611335039138794 sec
# Simulation time: 12.076862812042236 sec
# Simulation time: 11.83100700378418 sec
# Simulation time: 11.377920866012573 sec
# Simulation time: 11.743401050567627 sec
# Simulation time: 11.711664915084839 sec
# Simulation time: 11.703659057617188 sec
# Simulation time: 11.731744050979614 sec
# Simulation time: 11.75580382347107 sec
# Simulation time: 11.693823337554932 sec
# Simulation time: 11.690025091171265 sec
# Simulation time: 11.780406951904297 sec
# Simulation time: 11.617637872695923 sec
# Simulation time: 11.74062991142273 sec
# Simulation time: 11.548382997512817 sec
# Simulation time: 11.507515907287598 sec
# Simulation time: 11.553587913513184 sec
# Simulation time: 11.678820133209229 sec
# Simulation time: 11.738686800003052 sec
# Simulation time: 11.641560792922974 sec
# Simulation time: 11.615588188171387 sec
# Simulation time: 11.664311170578003 sec
# Simulation time: 11.677797079086304 sec
# Simulation time: 11.761738061904907 sec
# Simulation time: 11.487281799316406 sec
# Simulation time: 11.548964977264404 sec
# Simulation time: 11.48655891418457 sec
# Simulation time: 11.670330047607422 sec
# Simulation time: 11.94161319732666 sec
# Simulation time: 11.81841516494751 sec
# Simulation time: 11.527034997940063 sec
# Simulation time: 11.774529218673706 sec
# Simulation time: 11.642805099487305 sec
# Simulation time: 11.726166009902954 sec
# Simulation time: 11.659197092056274 sec
# Simulation time: 11.893594026565552 sec
# Simulation time: 11.86345911026001 sec
# Simulation time: 11.853009223937988 sec
# Simulation time: 11.843647003173828 sec
# Simulation time: 11.622627019882202 sec
# Simulation time: 11.799296855926514 sec
# Simulation time: 11.707533121109009 sec
# Simulation time: 11.999490976333618 sec
# Simulation time: 11.804643154144287 sec
# Simulation time: 11.454499959945679 sec
# Simulation time: 11.836777210235596 sec
# Simulation time: 11.601574897766113 sec
# Simulation time: 11.61849308013916 sec
# Simulation time: 11.73868703842163 sec
# Simulation time: 11.498941898345947 sec
# Simulation time: 11.602989912033081 sec
# Simulation time: 11.559360027313232 sec
# Simulation time: 11.72837495803833 sec
# Simulation time: 11.616772174835205 sec
# Simulation time: 12.111358880996704 sec
# Simulation time: 11.7252197265625 sec
# Simulation time: 11.402050018310547 sec
# Simulation time: 11.69136905670166 sec
# Simulation time: 11.644906997680664 sec
# Simulation time: 11.725911140441895 sec
# Simulation time: 11.931210994720459 sec
# Simulation time: 11.68791913986206 sec
# Simulation time: 11.640685796737671 sec
# Simulation time: 12.086004972457886 sec
# Simulation time: 11.76931095123291 sec
# Simulation time: 11.45841097831726 sec
# Simulation time: 11.903679847717285 sec
# Simulation time: 11.553632974624634 sec
# Simulation time: 11.757586002349854 sec
# Simulation time: 11.554117202758789 sec
# Simulation time: 11.791414737701416 sec
# Simulation time: 12.127804279327393 sec
# Simulation time: 11.647753238677979 sec
# Simulation time: 11.739369869232178 sec
# Simulation time: 11.718216180801392 sec
# Simulation time: 11.713008165359497 sec
# Simulation time: 11.734456062316895 sec
# Simulation time: 11.455984830856323 sec
# Simulation time: 11.403290033340454 sec
# Simulation time: 11.55266785621643 sec
# Simulation time: 11.655647993087769 sec
# Simulation time: 11.638544082641602 sec
# Simulation time: 11.76389193534851 sec
# Simulation time: 11.558753728866577 sec
# Simulation time: 11.820611000061035 sec
# Simulation time: 11.728814125061035 sec
# Simulation time: 11.844552040100098 sec
# Simulation time: 11.588136911392212 sec
# Simulation time: 11.755084037780762 sec
# Simulation time: 11.712177991867065 sec
# Simulation time: 11.557446956634521 sec
# Simulation time: 11.499503135681152 sec
# Simulation time: 11.683053970336914 sec
# Simulation time: 11.385328769683838 sec
# Simulation time: 11.611834049224854 sec
# Simulation time: 11.410566329956055 sec
# Simulation time: 11.585506677627563 sec
# Simulation time: 11.748734951019287 sec
# Simulation time: 11.709905862808228 sec
# Simulation time: 11.502772092819214 sec
# Simulation time: 11.66570520401001 sec
# Simulation time: 11.501031875610352 sec
# Simulation time: 11.721108198165894 sec
# Simulation time: 11.377381086349487 sec
# Simulation time: 11.73004698753357 sec
# Simulation time: 11.605488061904907 sec
# Simulation time: 11.568620920181274 sec
# Simulation time: 11.794812202453613 sec
# Simulation time: 11.810754776000977 sec
# Simulation time: 11.573377847671509 sec
# Simulation time: 11.662418842315674 sec
# Simulation time: 11.853417873382568 sec
# Simulation time: 11.687098979949951 sec
# Simulation time: 11.716145992279053 sec
# Simulation time: 11.759140014648438 sec
# Simulation time: 11.751054048538208 sec
# Simulation time: 11.46618103981018 sec
# Simulation time: 11.624639987945557 sec
# Simulation time: 11.441919088363647 sec
# Simulation time: 11.609215021133423 sec
# Simulation time: 11.501979112625122 sec
# Simulation time: 11.884697914123535 sec
# Simulation time: 12.01413893699646 sec
# Simulation time: 11.484693050384521 sec
# Simulation time: 11.746913194656372 sec
# Simulation time: 11.92785096168518 sec
# Simulation time: 11.554347038269043 sec
# Simulation time: 11.589033126831055 sec
# Simulation time: 11.85337209701538 sec
# Simulation time: 11.543753862380981 sec
# Simulation time: 11.735310077667236 sec
# Simulation time: 11.79834508895874 sec
# Simulation time: 11.499098777770996 sec
# Simulation time: 11.793660879135132 sec
# Simulation time: 11.618591070175171 sec
# Simulation time: 11.565744876861572 sec
# Simulation time: 11.714610815048218 sec
# Simulation time: 11.584860801696777 sec
# Simulation time: 11.632063150405884 sec
# Simulation time: 11.547096729278564 sec
# Simulation time: 11.798301219940186 sec
# Simulation time: 11.515084743499756 sec
# Simulation time: 11.647276878356934 sec
# Simulation time: 11.644773006439209 sec
# Simulation time: 11.589842796325684 sec
# Simulation time: 11.695592880249023 sec
# Simulation time: 11.499644041061401 sec
# Simulation time: 11.636317014694214 sec
# Simulation time: 11.623886823654175 sec
# Simulation time: 11.941822052001953 sec
# Simulation time: 11.52607798576355 sec
# Simulation time: 11.577582836151123 sec
# Simulation time: 11.672348976135254 sec
# Simulation time: 11.909220933914185 sec
# Simulation time: 11.57982587814331 sec
# Simulation time: 11.96530795097351 sec
# Simulation time: 11.806333303451538 sec
# Simulation time: 11.706700801849365 sec
# Simulation time: 11.318692207336426 sec
# Simulation time: 11.743045330047607 sec
# Simulation time: 11.45660400390625 sec
# Simulation time: 11.78794813156128 sec

# %%
print('Case 2, High k_yz')
# Create figure and plot 
fig, axs = plt.subplots(1, 2, figsize=(16,5))
axs[0].hist(response_time_off_to_on,bins=50,color='blue')
axs[0].set_title('OFF to ON')
axs[0].axvline(x=np.mean(response_time_off_to_on),color='green',
              linewidth=5)

axs[1].hist(response_time_on_to_off,bins=50,color='red')
axs[1].set_title('ON to OFF')
axs[1].axvline(x=np.mean(response_time_on_to_off),color='darkmagenta',
              linewidth=5)

# for ax in axs.flat:
#     ax.set(xlabel='Response time', ylabel='Count',)
for ax in axs.flat:
    ax.set(xlabel='Response time', ylabel='Count',
          xlim=(0,700))
    
# Hide x labels and tick labels for top plots and y ticks for right plots.
for ax in axs.flat:
    ax.label_outer()

sns.despine()
    
plt.show()
# Out:
# Case 2, High k_yz

# %%
# Case 2 - Response time calculation - low k_yz
By = 1; beta_y = 3; alpha_y = 0.01;
Bz = 1; beta_z = 3; alpha_z = 0.01;
k_xy = 1; k_xz = 1; k_yz = 0.01 *10**0;
h = 0.1
y_0 = 10
z_0 = 10
x = np.array([y_0,z_0]).reshape(1,2)
T = 10000
time_on_init = T//3
time_on_end = 2*T//3

Num_realizations = 200
response_time_off_to_on = np.zeros(Num_realizations)
response_time_on_to_off = np.zeros(Num_realizations)
threshold = 5

# @jit()
for i in range(Num_realizations):
    start_time = time.time() # start timing
    np.random.seed(i)
    x = np.array([y_0,z_0]).reshape(1,2)
    x,t_x = sim_case2(x,By,beta_y,alpha_y,Bz,beta_z,alpha_z,
                      k_xy,k_xz,k_yz,T,time_on_init,time_on_end)
    # Compute OFF to ON response time
    indx_start_X_on = np.argmin(np.abs(t_x-T//3))
    indx_end_X_on = np.argmin(np.abs(t_x-2*T//3))
    x_mean_X_on = np.mean(x[indx_start_X_on:indx_end_X_on,1])
    response_time_off_to_on[i] = t_x[(np.abs(x[:,1]-x_mean_X_on)<threshold) 
                                     & (t_x>time_on_init)][0] - time_on_init
    # Compute ON to OFF response time
    x_mean_X_off = np.mean(x[indx_end_X_on:-1,1])
    response_time_on_to_off[i] = t_x[(np.abs(x[:,1]-x_mean_X_off)<threshold) 
                                     & (t_x>time_on_end)][0] - time_on_end
    stop_time = time.time() # stop timing
    print('Simulation time:',stop_time-start_time,'sec')
# Out:
# Simulation time: 9.319304943084717 sec
# Simulation time: 9.442982912063599 sec
# Simulation time: 9.561686038970947 sec
# Simulation time: 9.876665115356445 sec
# Simulation time: 9.668237924575806 sec
# Simulation time: 9.652443885803223 sec
# Simulation time: 9.439781188964844 sec
# Simulation time: 9.390629768371582 sec
# Simulation time: 9.405712127685547 sec
# Simulation time: 9.459458112716675 sec
# Simulation time: 9.260493040084839 sec
# Simulation time: 9.382446050643921 sec
# Simulation time: 9.498575925827026 sec
# Simulation time: 9.379287719726562 sec
# Simulation time: 9.433971881866455 sec
# Simulation time: 9.588871955871582 sec
# Simulation time: 9.531176805496216 sec
# Simulation time: 9.394921064376831 sec
# Simulation time: 9.338744163513184 sec
# Simulation time: 9.53283405303955 sec
# Simulation time: 9.416888952255249 sec
# Simulation time: 9.479783296585083 sec
# Simulation time: 9.548973798751831 sec
# Simulation time: 9.399590253829956 sec
# Simulation time: 9.410275936126709 sec
# Simulation time: 9.483288049697876 sec
# Simulation time: 9.385286092758179 sec
# Simulation time: 9.534929275512695 sec
# Simulation time: 9.533271074295044 sec
# Simulation time: 9.19428825378418 sec
# Simulation time: 9.586046934127808 sec
# Simulation time: 9.303109884262085 sec
# Simulation time: 9.38935399055481 sec
# Simulation time: 9.297637939453125 sec
# Simulation time: 9.371901035308838 sec
# Simulation time: 9.269524812698364 sec
# Simulation time: 9.507457971572876 sec
# Simulation time: 9.542799949645996 sec
# Simulation time: 9.418836116790771 sec
# Simulation time: 9.706647157669067 sec
# Simulation time: 9.479491949081421 sec
# Simulation time: 9.239450216293335 sec
# Simulation time: 9.741405963897705 sec
# Simulation time: 9.302190065383911 sec
# Simulation time: 9.258556842803955 sec
# Simulation time: 9.291938066482544 sec
# Simulation time: 9.492572784423828 sec
# Simulation time: 9.529041051864624 sec
# Simulation time: 9.30930781364441 sec
# Simulation time: 9.442215204238892 sec
# Simulation time: 9.471885919570923 sec
# Simulation time: 9.409823894500732 sec
# Simulation time: 9.285259008407593 sec
# Simulation time: 9.460170984268188 sec
# Simulation time: 9.367315769195557 sec
# Simulation time: 9.641279220581055 sec
# Simulation time: 9.666465997695923 sec
# Simulation time: 9.366244077682495 sec
# Simulation time: 9.547881841659546 sec
# Simulation time: 10.41447401046753 sec
# Simulation time: 9.510265827178955 sec
# Simulation time: 9.622288227081299 sec
# Simulation time: 9.36167287826538 sec
# Simulation time: 9.66762089729309 sec
# Simulation time: 9.500948905944824 sec
# Simulation time: 9.565295696258545 sec
# Simulation time: 9.598887920379639 sec
# Simulation time: 9.906009912490845 sec
# Simulation time: 10.174565076828003 sec
# Simulation time: 10.134899854660034 sec
# Simulation time: 9.563366889953613 sec
# Simulation time: 9.57686185836792 sec
# Simulation time: 9.559489011764526 sec
# Simulation time: 9.386015892028809 sec
# Simulation time: 9.636061906814575 sec
# Simulation time: 9.51400089263916 sec
# Simulation time: 9.571254014968872 sec
# Simulation time: 9.586763858795166 sec
# Simulation time: 9.462354898452759 sec
# Simulation time: 9.397150993347168 sec
# Simulation time: 9.484989881515503 sec
# Simulation time: 9.5764799118042 sec
# Simulation time: 9.624753952026367 sec
# Simulation time: 9.35521912574768 sec
# Simulation time: 9.526524066925049 sec
# Simulation time: 9.548274993896484 sec
# Simulation time: 9.539139986038208 sec
# Simulation time: 9.497052192687988 sec
# Simulation time: 9.383983850479126 sec
# Simulation time: 9.249126195907593 sec
# Simulation time: 9.590647220611572 sec
# Simulation time: 9.245512962341309 sec
# Simulation time: 9.401936054229736 sec
# Simulation time: 9.602625846862793 sec
# Simulation time: 10.657600164413452 sec
# Simulation time: 10.619639158248901 sec
# Simulation time: 9.986252069473267 sec
# Simulation time: 10.777703285217285 sec
# Simulation time: 11.043446063995361 sec
# Simulation time: 10.703960180282593 sec
# Simulation time: 9.380433320999146 sec
# Simulation time: 9.44703197479248 sec
# Simulation time: 10.06560492515564 sec
# Simulation time: 9.957199096679688 sec
# Simulation time: 11.025179862976074 sec
# Simulation time: 10.050009965896606 sec
# Simulation time: 9.997301816940308 sec
# Simulation time: 9.817235946655273 sec
# Simulation time: 10.813900232315063 sec
# Simulation time: 9.881569147109985 sec
# Simulation time: 9.538377046585083 sec
# Simulation time: 9.591940879821777 sec
# Simulation time: 9.822746276855469 sec
# Simulation time: 10.283213138580322 sec
# Simulation time: 10.098972797393799 sec
# Simulation time: 9.728646993637085 sec
# Simulation time: 9.50043511390686 sec
# Simulation time: 9.272379159927368 sec
# Simulation time: 9.56536602973938 sec
# Simulation time: 9.28148603439331 sec
# Simulation time: 9.700371980667114 sec
# Simulation time: 9.488010883331299 sec
# Simulation time: 9.625948190689087 sec
# Simulation time: 9.39128589630127 sec
# Simulation time: 9.492130041122437 sec
# Simulation time: 9.529515981674194 sec
# Simulation time: 9.363133192062378 sec
# Simulation time: 9.504072189331055 sec
# Simulation time: 9.42731523513794 sec
# Simulation time: 9.279957294464111 sec
# Simulation time: 9.551631927490234 sec
# Simulation time: 9.577940940856934 sec
# Simulation time: 9.691931009292603 sec
# Simulation time: 9.435680866241455 sec
# Simulation time: 9.785920858383179 sec
# Simulation time: 10.219362258911133 sec
# Simulation time: 9.925043106079102 sec
# Simulation time: 9.714447975158691 sec
# Simulation time: 9.712982892990112 sec
# Simulation time: 9.580877780914307 sec
# Simulation time: 9.600200891494751 sec
# Simulation time: 9.506191730499268 sec
# Simulation time: 9.58336591720581 sec
# Simulation time: 9.728760957717896 sec
# Simulation time: 9.628071069717407 sec
# Simulation time: 9.691975831985474 sec
# Simulation time: 9.345743894577026 sec
# Simulation time: 9.438678979873657 sec
# Simulation time: 9.69471263885498 sec
# Simulation time: 9.520156145095825 sec
# Simulation time: 9.536428928375244 sec
# Simulation time: 9.645062685012817 sec
# Simulation time: 9.530751943588257 sec
# Simulation time: 9.6265389919281 sec
# Simulation time: 9.54916787147522 sec
# Simulation time: 9.694415092468262 sec
# Simulation time: 9.389579057693481 sec
# Simulation time: 9.336357831954956 sec
# Simulation time: 9.575453042984009 sec
# Simulation time: 9.729726314544678 sec
# Simulation time: 9.634101867675781 sec
# Simulation time: 10.215282917022705 sec
# Simulation time: 10.42979097366333 sec
# Simulation time: 10.428582906723022 sec
# Simulation time: 10.259109735488892 sec
# Simulation time: 10.189346075057983 sec
# Simulation time: 10.347753047943115 sec
# Simulation time: 12.626365900039673 sec
# Simulation time: 12.466005802154541 sec
# Simulation time: 12.389490842819214 sec
# Simulation time: 12.804486989974976 sec
# Simulation time: 12.70801305770874 sec
# Simulation time: 13.176812171936035 sec
# Simulation time: 13.397155284881592 sec
# Simulation time: 13.380568027496338 sec
# Simulation time: 13.400020122528076 sec
# Simulation time: 13.66651701927185 sec
# Simulation time: 14.810080766677856 sec
# Simulation time: 13.8164541721344 sec
# Simulation time: 14.129983901977539 sec
# Simulation time: 13.90505313873291 sec
# Simulation time: 13.682586908340454 sec
# Simulation time: 13.622193098068237 sec
# Simulation time: 13.651289939880371 sec
# Simulation time: 13.978203058242798 sec
# Simulation time: 13.355709075927734 sec
# Simulation time: 13.793771028518677 sec
# Simulation time: 14.400179147720337 sec
# Simulation time: 13.770414113998413 sec
# Simulation time: 13.67648983001709 sec
# Simulation time: 13.64548110961914 sec
# Simulation time: 13.625678062438965 sec
# Simulation time: 13.451572895050049 sec
# Simulation time: 14.454959869384766 sec
# Simulation time: 13.582350015640259 sec
# Simulation time: 13.615628004074097 sec
# Simulation time: 13.366950988769531 sec
# Simulation time: 13.754370927810669 sec
# Simulation time: 13.453068017959595 sec
# Simulation time: 14.368942260742188 sec

# %%
print('Case 2, Low k_yz')
# Create figure and plot 
fig, axs = plt.subplots(1, 2, figsize=(16,5))
axs[0].hist(response_time_off_to_on,bins=50,color='blue')
axs[0].set_title('OFF to ON')
axs[0].axvline(x=np.mean(response_time_off_to_on),color='green',
              linewidth=5)

axs[1].hist(response_time_on_to_off,bins=50,color='red')
axs[1].set_title('ON to OFF')
axs[1].axvline(x=np.mean(response_time_on_to_off),color='darkmagenta',
              linewidth=5)

for ax in axs.flat:
    ax.set(xlabel='Response time', ylabel='Count',
          xlim=(0,700))
    
# Hide x labels and tick labels for top plots and y ticks for right plots.
for ax in axs.flat:
    ax.label_outer()

sns.despine()
    
plt.show()
# Out:
# Case 2, Low k_yz

# %% [markdown]
# ## What's the distribution of $Z$ when $X_*=1$?

# %%
# Case 1 - sample simulation
By = 1; beta_y = 3; alpha_y = 0.01;
Bz = 1; beta_z = 3; alpha_z = 0.01;
k_xy = 1; k_xz = 1; k_yz = 0.01 *10**0; # Strong Y-Z regulation.
h = 0.1
y_0 = 200
z_0 = 200
x = np.array([y_0,z_0]).reshape(1,2)
T = 10000
time_on_init = 0
time_on_end = T+1

np.random.seed(20)

x1,t_x1 = sim_case1(x,By,beta_y,alpha_y,Bz,beta_z,alpha_z,k_xy,k_xz,k_yz,
                  T,time_on_init,time_on_end)

x2,t_x2 = sim_case2(x,By,beta_y,alpha_y,Bz,beta_z,alpha_z,k_xy,k_xz,k_yz,
                  T,time_on_init,time_on_end)

# %%
# Plot time series and histogram for case I and II
fig, axs = plt.subplots(3, 2, figsize=(20,20))
axs[0, 0].plot(t_x1, x1[:,1],label='Z')
axs[0, 0].plot(t_x1, x1[:,0],label='Y')
axs[0, 0].set_title('Case I')
axs[0, 0].legend()
axs[0, 0].axvspan(time_on_init, time_on_end, alpha=0.2, color='black')
axs[0, 0].set(xlabel='Time', ylabel='Concentration',xlim=((0,T)))

axs[0, 1].plot(t_x2, x2[:,1])
axs[0, 1].plot(t_x2, x2[:,0])
axs[0, 1].set_title('Case II')
axs[0, 1].axvspan(time_on_init, time_on_end, alpha=0.2, color='black')
axs[0, 1].set(xlabel='Time',xlim=((0,T)))

axs[1, 0].hist(x1[:,1],bins=50)
axs[1, 0].axvline(x=np.mean(x1[:,1]), color='lightblue',linewidth=7)
axs[1, 0].set(xlabel='Z concentration', ylabel='Frequency')

axs[1, 1].hist(x2[:,1],bins=50)
axs[1, 1].axvline(x=np.mean(x2[:,1]), color='lightblue',linewidth=7)
axs[1, 1].set(xlabel='Z concentration')

axs[2, 0].hist(x1[:,0],bins=50,color='tab:orange')
axs[2, 0].axvline(x=np.mean(x1[:,0]), color='red',linewidth=7)
axs[2, 0].set(xlabel='Y concentration', ylabel='Frequency')

axs[2, 1].hist(x2[:,0],bins=50,color='tab:orange')
axs[2, 1].axvline(x=np.mean(x2[:,0]), color='red',linewidth=7)
axs[2, 1].set(xlabel='Y concentration')

# # Hide x labels and tick labels for top plots and y ticks for right plots.
# for ax in axs.flat:
#     ax.label_outer()

plt.show()

# %%
# Kolmogorov - Smirnov Test on Z distribution
from scipy import stats
stats.ks_2samp(x1[:,1],x2[:,1])
# Out:
# Ks_2sampResult(statistic=0.040596293250304644, pvalue=4.679148614346877e-56)

# %%
# Kolmogorov - Smirnov Test on Y distribution
stats.ks_2samp(x1[:,0],x2[:,0])
# Out:
# Ks_2sampResult(statistic=0.06574705996682395, pvalue=2.440342644739728e-146)

# %%
print('Mean Z case I', round(np.mean(x1[:,1]),3), 'Mean Z in case II', round(np.mean(x2[:,1]),3))
print('Mean Y case I', round(np.mean(x1[:,0]),3), 'Mean Y in case II', round(np.mean(x2[:,0]),3))
print('Std Z case I', round(np.std(x1[:,1]),3), 'Std Z in case II', round(np.std(x2[:,1]),3))
print('Std Y case I', round(np.std(x1[:,0]),3), 'Std Y in case II', round(np.std(x2[:,0]),3))
# Out:
# Mean Z case I 141.259 Mean Z in case II 141.213
# Mean Y case I 245.993 Mean Y in case II 248.636
# Std Z case I 11.601 Std Z in case II 12.57
# Std Y case I 14.172 Std Y in case II 14.521
